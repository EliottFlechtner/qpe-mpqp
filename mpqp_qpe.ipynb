# %%
# %pip install mpqp
# Out:
# Requirement already satisfied: mpqp in ./.venv/lib/python3.12/site-packages (0.4.0)
# Requirement already satisfied: aenum==3.1.15 in ./.venv/lib/python3.12/site-packages (from mpqp) (3.1.15)
# Requirement already satisfied: amazon-braket-default-simulator==1.23.2 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.23.2)
# Requirement already satisfied: amazon-braket-sdk==1.79.1 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.79.1)
# Requirement already satisfied: anytree>=2.12.1 in ./.venv/lib/python3.12/site-packages (from mpqp) (2.13.0)
# Requirement already satisfied: aws-configure==2.1.8 in ./.venv/lib/python3.12/site-packages (from mpqp) (2.1.8)
# Requirement already satisfied: azure-quantum==3.1.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (3.1.0)
# Requirement already satisfied: boto3==1.35.82 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.35.82)
# Requirement already satisfied: cirq-aqt==1.3.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: cirq-core==1.3.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: cirq-google==1.3.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: cirq-ionq==1.3.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.3.0)
# Requirement already satisfied: cvxpy==1.4.3 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.4.3)
# Requirement already satisfied: jsonschema>=4.17.3 in ./.venv/lib/python3.12/site-packages (from mpqp) (4.24.0)
# Requirement already satisfied: myqlm-interop in ./.venv/lib/python3.12/site-packages (from mpqp) (1.10.0)
# Requirement already satisfied: myqlm==1.10.6 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.10.6)
# Requirement already satisfied: numba==0.60.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (0.60.0)
# Requirement already satisfied: numpy>=1.26.4 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.26.4)
# Requirement already satisfied: osqp==1.0.1 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.0.1)
# Requirement already satisfied: pick==2.2.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (2.2.0)
# Requirement already satisfied: pylatexenc==2.10 in ./.venv/lib/python3.12/site-packages (from mpqp) (2.10)
# Requirement already satisfied: python-dotenv>=1.0.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.1.0)
# Requirement already satisfied: qiskit-aer==0.15.1 in ./.venv/lib/python3.12/site-packages (from mpqp) (0.15.1)
# Requirement already satisfied: qiskit-ibm-runtime==0.31.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (0.31.0)
# Requirement already satisfied: qiskit==1.2.4 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.2.4)
# Requirement already satisfied: qsimcirq in ./.venv/lib/python3.12/site-packages (from mpqp) (0.21.0)
# Requirement already satisfied: scipy>=1.11.4 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.15.3)
# Requirement already satisfied: symengine>=0.11.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (0.13.0)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.12/site-packages (from mpqp) (1.13.1)
# Requirement already satisfied: termcolor==2.4.0 in ./.venv/lib/python3.12/site-packages (from mpqp) (2.4.0)
# Requirement already satisfied: typeguard>=4.2.1 in ./.venv/lib/python3.12/site-packages (from mpqp) (4.4.3)
# Requirement already satisfied: wheel in ./.venv/lib/python3.12/site-packages (from mpqp) (0.45.1)
# Requirement already satisfied: opt-einsum in ./.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (3.4.0)
# Requirement already satisfied: pydantic>2 in ./.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (2.11.7)
# Requirement already satisfied: antlr4-python3-runtime==4.9.2 in ./.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (4.9.2)
# Requirement already satisfied: amazon-braket-schemas>=1.21.2 in ./.venv/lib/python3.12/site-packages (from amazon-braket-default-simulator==1.23.2->mpqp) (1.24.0)
# Requirement already satisfied: oqpy~=0.3.5 in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (0.3.7)
# Requirement already satisfied: backoff in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (2.2.1)
# Requirement already satisfied: boltons in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (25.0.0)
# Requirement already satisfied: cloudpickle==2.2.1 in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (2.2.1)
# Requirement already satisfied: nest-asyncio in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.6.0)
# Requirement already satisfied: networkx in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (3.5)
# Requirement already satisfied: openpulse in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.0.1)
# Requirement already satisfied: openqasm3 in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.0.1)
# Requirement already satisfied: backports.entry-points-selectable in ./.venv/lib/python3.12/site-packages (from amazon-braket-sdk==1.79.1->mpqp) (1.3.0)
# Requirement already satisfied: awscli in ./.venv/lib/python3.12/site-packages (from aws-configure==2.1.8->mpqp) (1.36.40)
# Requirement already satisfied: botocore in ./.venv/lib/python3.12/site-packages (from aws-configure==2.1.8->mpqp) (1.35.99)
# Requirement already satisfied: azure-core<2.0,>=1.30 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (1.34.0)
# Requirement already satisfied: azure-identity<2.0,>=1.17 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (1.23.0)
# Requirement already satisfied: azure-storage-blob==12.20 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (12.20.0)
# Requirement already satisfied: msrest<1.0,>=0.7.1 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (0.7.1)
# Requirement already satisfied: deprecated<2.0,>=1.2.12 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (1.2.18)
# Requirement already satisfied: Markdown>=3.4.1 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (3.8)
# Requirement already satisfied: python-markdown-math>=0.8 in ./.venv/lib/python3.12/site-packages (from azure-quantum==3.1.0->mpqp) (0.9)
# Requirement already satisfied: cryptography>=2.1.4 in ./.venv/lib/python3.12/site-packages (from azure-storage-blob==12.20->azure-quantum==3.1.0->mpqp) (45.0.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./.venv/lib/python3.12/site-packages (from azure-storage-blob==12.20->azure-quantum==3.1.0->mpqp) (4.14.0)
# Requirement already satisfied: isodate>=0.6.1 in ./.venv/lib/python3.12/site-packages (from azure-storage-blob==12.20->azure-quantum==3.1.0->mpqp) (0.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.venv/lib/python3.12/site-packages (from boto3==1.35.82->mpqp) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./.venv/lib/python3.12/site-packages (from boto3==1.35.82->mpqp) (0.10.4)
# Requirement already satisfied: requests~=2.18 in ./.venv/lib/python3.12/site-packages (from cirq-aqt==1.3.0->mpqp) (2.32.4)
# Requirement already satisfied: duet~=0.2.8 in ./.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (0.2.9)
# Requirement already satisfied: matplotlib~=3.0 in ./.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (3.10.3)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (2.3.0)
# Requirement already satisfied: sortedcontainers~=2.0 in ./.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (2.4.0)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from cirq-core==1.3.0->mpqp) (4.67.1)
# Requirement already satisfied: google-api-core>=1.14.0 in ./.venv/lib/python3.12/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (2.25.1)
# Requirement already satisfied: proto-plus>=1.20.0 in ./.venv/lib/python3.12/site-packages (from cirq-google==1.3.0->mpqp) (1.26.1)
# Requirement already satisfied: protobuf>=3.15.0 in ./.venv/lib/python3.12/site-packages (from cirq-google==1.3.0->mpqp) (6.31.1)
# Requirement already satisfied: ecos>=2 in ./.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (2.0.14)
# Requirement already satisfied: clarabel>=0.5.0 in ./.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (0.11.1)
# Requirement already satisfied: scs>=3.0 in ./.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (3.2.7.post2)
# Requirement already satisfied: pybind11 in ./.venv/lib/python3.12/site-packages (from cvxpy==1.4.3->mpqp) (2.13.6)
# Requirement already satisfied: qat-comm==1.6.1 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.6.1)
# Requirement already satisfied: qat-core==1.10.0 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.10.0)
# Requirement already satisfied: qat-devices==0.3.0 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.3.0)
# Requirement already satisfied: qat-fusion==0.1.0 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.1.0)
# Requirement already satisfied: qat-lang==3.1.0 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (3.1.0)
# Requirement already satisfied: qat-anapli==0.0.1 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.0.1)
# Requirement already satisfied: qat-variational==1.5.0 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.5.0)
# Requirement already satisfied: qlmaas==1.10.2 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.10.2)
# Requirement already satisfied: myqlm-clinalg==0.2.4 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (0.2.4)
# Requirement already satisfied: myqlm-contrib==1.9.5 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.9.5)
# Requirement already satisfied: myqlm-fermion==1.1.4 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.1.4)
# Requirement already satisfied: myqlm-simulators==1.9.5 in ./.venv/lib/python3.12/site-packages (from myqlm==1.10.6->mpqp) (1.9.5)
# Requirement already satisfied: bitstring in ./.venv/lib/python3.12/site-packages (from myqlm-fermion==1.1.4->myqlm==1.10.6->mpqp) (4.3.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in ./.venv/lib/python3.12/site-packages (from numba==0.60.0->mpqp) (0.43.0)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from osqp==1.0.1->mpqp) (3.1.6)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from osqp==1.0.1->mpqp) (80.9.0)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from osqp==1.0.1->mpqp) (1.5.1)
# Requirement already satisfied: thrift==0.20.0 in ./.venv/lib/python3.12/site-packages (from qat-comm==1.6.1->myqlm==1.10.6->mpqp) (0.20.0)
# Requirement already satisfied: wand in ./.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.6.13)
# Requirement already satisfied: dill in ./.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.4.0)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (11.2.1)
# Requirement already satisfied: svgwrite in ./.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (1.4.3)
# Requirement already satisfied: jax[cpu] in ./.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.6.1)
# Requirement already satisfied: IPython in ./.venv/lib/python3.12/site-packages (from qat-core==1.10.0->myqlm==1.10.6->mpqp) (9.3.0)
# Requirement already satisfied: ply==3.11 in ./.venv/lib/python3.12/site-packages (from qat-lang==3.1.0->myqlm==1.10.6->mpqp) (3.11)
# Requirement already satisfied: rustworkx>=0.15.0 in ./.venv/lib/python3.12/site-packages (from qiskit==1.2.4->mpqp) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./.venv/lib/python3.12/site-packages (from qiskit==1.2.4->mpqp) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in ./.venv/lib/python3.12/site-packages (from qiskit==1.2.4->mpqp) (5.4.1)
# Requirement already satisfied: psutil>=5 in ./.venv/lib/python3.12/site-packages (from qiskit-aer==0.15.1->mpqp) (7.0.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in ./.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (1.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in ./.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (2.4.0)
# Requirement already satisfied: websocket-client>=1.5.1 in ./.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in ./.venv/lib/python3.12/site-packages (from qiskit-ibm-runtime==0.31.0->mpqp) (0.66.2)
# Requirement already satisfied: prompt-toolkit in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (3.0.51)
# Requirement already satisfied: prettytable in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (3.16.0)
# Requirement already satisfied: pyOpenSSL in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (25.1.0)
# Requirement already satisfied: cffi in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (1.17.1)
# Requirement already satisfied: qat-hardware>=1.4.0 in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (1.5.0)
# Requirement already satisfied: qat-quops>=1.3.4 in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (1.4.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.12/site-packages (from qlmaas==1.10.2->myqlm==1.10.6->mpqp) (25.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.12/site-packages (from sympy==1.13.1->mpqp) (1.3.0)
# Requirement already satisfied: six>=1.7.2 in ./.venv/lib/python3.12/site-packages (from thrift==0.20.0->qat-comm==1.6.1->myqlm==1.10.6->mpqp) (1.17.0)
# Requirement already satisfied: msal>=1.30.0 in ./.venv/lib/python3.12/site-packages (from azure-identity<2.0,>=1.17->azure-quantum==3.1.0->mpqp) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in ./.venv/lib/python3.12/site-packages (from azure-identity<2.0,>=1.17->azure-quantum==3.1.0->mpqp) (1.3.1)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.12/site-packages (from deprecated<2.0,>=1.2.12->azure-quantum==3.1.0->mpqp) (1.17.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.12/site-packages (from matplotlib~=3.0->cirq-core==1.3.0->mpqp) (3.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from msrest<1.0,>=0.7.1->azure-quantum==3.1.0->mpqp) (2025.6.15)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in ./.venv/lib/python3.12/site-packages (from msrest<1.0,>=0.7.1->azure-quantum==3.1.0->mpqp) (2.0.0)
# Requirement already satisfied: mypy-extensions>=0.2.0 in ./.venv/lib/python3.12/site-packages (from oqpy~=0.3.5->amazon-braket-sdk==1.79.1->mpqp) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests~=2.18->cirq-aqt==1.3.0->mpqp) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests~=2.18->cirq-aqt==1.3.0->mpqp) (3.10)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.12/site-packages (from cffi->qlmaas==1.10.2->myqlm==1.10.6->mpqp) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in ./.venv/lib/python3.12/site-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (1.70.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in ./.venv/lib/python3.12/site-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (2.40.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (4.7.2)
# Requirement already satisfied: pyasn1>=0.1.3 in ./.venv/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (0.6.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in ./.venv/lib/python3.12/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in ./.venv/lib/python3.12/site-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->mpqp) (1.73.0)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.2 in ./.venv/lib/python3.12/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime==0.31.0->mpqp) (3.24.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.10.1 in ./.venv/lib/python3.12/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.2->ibm-platform-services>=0.22.6->qiskit-ibm-runtime==0.31.0->mpqp) (2.10.1)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=4.17.3->mpqp) (0.25.1)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator==1.23.2->mpqp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in ./.venv/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator==1.23.2->mpqp) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.12/site-packages (from pydantic>2->amazon-braket-default-simulator==1.23.2->mpqp) (0.4.1)
# Requirement already satisfied: qutip in ./.venv/lib/python3.12/site-packages (from qat-hardware>=1.4.0->qlmaas==1.10.2->myqlm==1.10.6->mpqp) (5.2.0)
# Requirement already satisfied: pyspnego>=0.4.0 in ./.venv/lib/python3.12/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime==0.31.0->mpqp) (0.11.2)
# Requirement already satisfied: oauthlib>=3.0.0 in ./.venv/lib/python3.12/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0,>=0.7.1->azure-quantum==3.1.0->mpqp) (3.2.2)
# Requirement already satisfied: pbr>=2.0.0 in ./.venv/lib/python3.12/site-packages (from stevedore>=3.0.0->qiskit==1.2.4->mpqp) (6.1.1)
# Requirement already satisfied: docutils<0.17,>=0.10 in ./.venv/lib/python3.12/site-packages (from awscli->aws-configure==2.1.8->mpqp) (0.16)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in ./.venv/lib/python3.12/site-packages (from awscli->aws-configure==2.1.8->mpqp) (6.0.2)
# Requirement already satisfied: colorama<0.4.7,>=0.2.5 in ./.venv/lib/python3.12/site-packages (from awscli->aws-configure==2.1.8->mpqp) (0.4.6)
# Requirement already satisfied: qiskit-ionq<0.6,>=0.5 in ./.venv/lib/python3.12/site-packages (from azure-quantum[qiskit]->mpqp) (0.5.13)
# Requirement already satisfied: qsharp<2.0,>=1.9.0 in ./.venv/lib/python3.12/site-packages (from qsharp[qiskit]<2.0,>=1.9.0; extra == "qiskit"->azure-quantum[qiskit]->mpqp) (1.17.0)
# Requirement already satisfied: pyqir<0.11,>=0.10.6 in ./.venv/lib/python3.12/site-packages (from azure-quantum[qiskit]->mpqp) (0.10.9)
# Requirement already satisfied: decorator>=5.1.0 in ./.venv/lib/python3.12/site-packages (from qiskit-ionq<0.6,>=0.5->azure-quantum[qiskit]->mpqp) (5.2.1)
# Requirement already satisfied: importlib-metadata>=4.11.4 in ./.venv/lib/python3.12/site-packages (from qiskit-ionq<0.6,>=0.5->azure-quantum[qiskit]->mpqp) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata>=4.11.4->qiskit-ionq<0.6,>=0.5->azure-quantum[qiskit]->mpqp) (3.23.0)
# Requirement already satisfied: bitarray<4.0,>=3.0.0 in ./.venv/lib/python3.12/site-packages (from bitstring->myqlm-fermion==1.1.4->myqlm==1.10.6->mpqp) (3.4.2)
# Requirement already satisfied: ipython-pygments-lexers in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (4.9.0)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.12/site-packages (from IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (5.14.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.12/site-packages (from prompt-toolkit->qlmaas==1.10.2->myqlm==1.10.6->mpqp) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.12/site-packages (from jedi>=0.16->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.12/site-packages (from pexpect>4.3->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.7.0)
# Requirement already satisfied: jaxlib<=0.6.1,>=0.6.1 in ./.venv/lib/python3.12/site-packages (from jax[cpu]->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.6.1)
# Requirement already satisfied: ml_dtypes>=0.5.0 in ./.venv/lib/python3.12/site-packages (from jax[cpu]->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->osqp==1.0.1->mpqp) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->cirq-core==1.3.0->mpqp) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->cirq-core==1.3.0->mpqp) (2025.2)
# Requirement already satisfied: absl-py in ./.venv/lib/python3.12/site-packages (from qsimcirq->mpqp) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.12/site-packages (from stack_data->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.12/site-packages (from stack_data->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.12/site-packages (from stack_data->IPython->qat-core==1.10.0->myqlm==1.10.6->mpqp) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mpqp import QCircuit
from mpqp.gates import H

def prepare_initial_state(n_precision_qubits, eigenstate_circuit):
    """
    Prepare the initial state for the Quantum Phase Estimation (QPE) algorithm.
    This function creates a quantum circuit that initializes the precision qubits
    to the state |+> and appends the provided eigenstate circuit to the bottom qubits.
    The total number of qubits in the circuit is the sum of the precision qubits
    and the qubits in the eigenstate circuit.

    :param eigenstate_circuit: The quantum circuit representing the eigenstate.
    :param n_precision_qubits: The number of precision qubits to be used in the QPE.
    :return: A QCircuit object representing the initial state for QPE.
    """

    # Create an empty circuit with total number of qubits
    n_eigenstate_qubits = eigenstate_circuit.nb_qubits
    total_qubits = n_precision_qubits + n_eigenstate_qubits
    circ = QCircuit(nb_qubits=total_qubits, label="QPE Circuit")

    # Define the precision qubits and the circuits qubits range indices
    precisions = range(n_precision_qubits)
    circuits = range(n_precision_qubits, total_qubits)

    # Apply Hadamard gates to precision qubits (index 0 to n-1)
    for i in range(n_precision_qubits):
        circ.add(H(i))

    # Append the given eigenstate circuit offset to the "bottom" qubits
    circ.append(eigenstate_circuit, qubits_offset=n_precision_qubits)

    # Return circuit in state |+>^n \otimes |eigenstate>
    return circ

# %%
from math import pi as PI
from mpqp.gates import CNOT, TOF, CP, S, S_dagger, CZ, X, Y, Z, T, Rz

def transform_to_controlled_gate(circ, gate, i, n, target):
    """
    Transform a single-target gate into its controlled version based on the precision qubit index.
    This function modifies the quantum circuit by adding the controlled version of the gate
    with the control qubit at position `i` and the target qubit at the specified
    target position (offset by `n`).

    :param circ: The quantum circuit to which the controlled gate will be added.
    :param gate: The single-target gate to be transformed into a controlled gate.
    :param i: The index of the precision qubit that acts as the control.
    :param n: The total number of precision qubits.
    :param target: The target qubit position (offset by `n`).
    :return: None
    """

    if isinstance(gate, CNOT): # CNOT -> TOF
        control = gate.controls[0] + n
        circ.add(TOF([i, control], target))
    elif isinstance(gate, X):
        circ.add(CNOT(i, target))
    elif isinstance(gate, S):
        circ.add(CP(PI/2, i, target))
    elif isinstance(gate, Y):
        circ.add(S(target))
        circ.add(CNOT(i, target))
        circ.add(S_dagger(target))
    elif isinstance(gate, Z):
        circ.add(CZ(i, target))
    elif isinstance(gate, T):
        circ.add(CP(PI/4, i, target))
    elif isinstance(gate, H):
        circ.add(Rz(PI, target))
        circ.add(Rz(PI/2, target))
        circ.add(CNOT(i, target))
        circ.add(Rz(-PI, target))
        circ.add(Rz(-PI/2, target))
    else:
        raise ValueError("Unknown single-target gate in controlled unitary.")

# %%
from mpqp import Barrier

def create_controlled_unitary(circ, unitary, n_precision_qubits):
    """
    Create controlled unitary operations for the Quantum Phase Estimation (QPE) algorithm.
    This function applies controlled unitary operations based on the provided unitary circuit
    and the number of precision qubits. The controlled unitary operations are applied
    in reverse order, starting from the highest precision qubit.
    The unitary circuit is transformed to its controlled version with the control qubit
    at the specified precision qubit position.

    :param circ: The quantum circuit to which the controlled unitary operations will be added.
    :param unitary: The quantum circuit representing the unitary operation to be controlled.
    :param n_precision_qubits: The number of precision qubits used in the QPE.
    :return: None
    """

    print("Applying controlled unitary operations.")
    n = n_precision_qubits
    precisions = range(n)

    # Loop through precision qubits in reverse order
    for i in precisions[::-1]:
        print(f"Applying controlled unitary for precision qubit {i}")
        # Apply controlled unitary operator 2^(n-i-1) times (1, 2, 4, ...)
        iterations = 2 ** (n - i - 1)
        print(f"Applying controlled unitary {iterations} times.")
        for k in range(iterations):
            print(f"\t{iterations-k} remaining")

            # Transform the unitary circuit to its controlled version with control qubit at position i
            for gate in unitary.gates:
                if len(gate.targets) == 1:
                    transform_to_controlled_gate(circ, gate, i, n, target=gate.targets[0] + n)
                else:
                    raise ValueError("Only single-target gates are supported in controlled unitary.")
        circ.add(Barrier())
    print("Controlled unitary operations applied.")

# %%
from mpqp.gates import SWAP, CRk
from math import floor

def build_inverse_qft(n_qubits):
    """
    Build the inverse Quantum Fourier Transform (QFT) circuit.
    This function constructs the inverse QFT circuit by adding SWAP gates for qubit reordering
    and applying controlled rotations and Hadamard gates in reverse order.
    The inverse QFT is essential for the Quantum Phase Estimation (QPE) algorithm to extract
    the phase information from the quantum state.

    :param n_qubits: The number of qubits in the circuit.
    :return: A QCircuit object representing the inverse QFT circuit over n_qubits.
    """

    qftc = QCircuit(n_qubits, label="Inverse QFT Circuit")

    # Add SWAP gates for qubit reordering
    qftc.add([SWAP(i, n_qubits - 1 - i) for i in range(int(floor(n_qubits / 2)))])

    # Apply controlled rotations and Hadamard gates in reverse order
    j = n_qubits - 1
    while j >= 0:
        qftc.add([CRk(i + 1 - j, i, j).inverse() for i in range(j + 1, n_qubits)])
        qftc.add(H(j))
        j -= 1

    return qftc


def append_inverse_qft(circ, n_precision_qubits):
    """
    Append the inverse Quantum Fourier Transform (QFT) to the circuit.
    This function adds the inverse QFT gates to the circuit, which is essential for
    the Quantum Phase Estimation (QPE) algorithm to extract the phase information from the
    quantum state.

    :param circ: The quantum circuit to which the inverse QFT will be appended.
    :param n: The number of precision qubits used in the QPE.
    :return: None
    """

    print("Appending inverse Quantum Fourier Transform (QFT).")

    # Append the inverse QFT to the circuit on the precision qubits only (no offset)
    circ.append(build_inverse_qft(n_precision_qubits), qubits_offset=0)
    circ.add(Barrier())

    print("Inverse QFT appended to the circuit.")

# %%
from mpqp.measures import BasisMeasure

def QPE(unitary, eigenstate_circuit, n_precision_qubits):
    """
    Quantum Phase Estimation (QPE) algorithm implementation.
    This function constructs a quantum circuit for the QPE algorithm, which estimates the phase
    of an eigenstate of a unitary operator. The circuit prepares an initial state, applies
    controlled unitary operations, applies the inverse Quantum Fourier Transform (QFT), and
    measures the precision qubits to obtain the estimated phase.

    :param unitary: The unitary operator whose eigenstate is being estimated.
    :param eigenstate_circuit: The circuit that prepares the eigenstate of the unitary
    :param n_precision_qubits: The number of precision qubits used in the QPE.
    :return: A QCircuit object representing the QPE circuit.
    """

    #### 1. Prepare the initial state |+>^n \otimes |eigenstate> ####
    n, m = n_precision_qubits, eigenstate_circuit.nb_qubits
    circ = prepare_initial_state(n_precision_qubits, eigenstate_circuit)

    #### 2. Apply controlled unitary operators ####
    create_controlled_unitary(circ, unitary, n_precision_qubits)

    #### 3. Apply inverse QFT to precision qubits ####
    append_inverse_qft(circ, n_precision_qubits)

    #### 4. Measure precision qubits ####
    circ.add(BasisMeasure(targets=list(range(n)), shots=1024))
    print("Measurement added to precision qubits.")

    # Add a barrier for clarity
    circ.add(Barrier())
    return circ

# %%
from mpqp import *
from mpqp.gates import *
from collections import defaultdict
from mpqp.execution import run, IBMDevice


def extract_phase_from_eigenstate(unitary, eigenstate_circuit, n_precision_qubits, device=IBMDevice.AER_SIMULATOR_STATEVECTOR):
    """
    Extract the phase from an eigenstate of a unitary operator using Quantum Phase Estimation (QPE).
    :param unitary: The unitary operator circuit whose eigenstate phase is to be estimated.
    :param eigenstate_circuit: The circuit that prepares the eigenstate of the unitary
    :param n_precision_qubits: The number of precision qubits used in the QPE.
    :param device: The quantum device to run the circuit on (default is AER simulator
    :return: The estimated phase as a float.
    """
    print("Starting Quantum Phase Estimation (QPE) to extract phase from eigenstate.")

    # Build & run the Quantum Phase Estimation (QPE) circuit
    qpe_circuit = QPE(unitary, eigenstate_circuit, n_precision_qubits)
    qpe_circuit.pretty_print()

    result = run(qpe_circuit, device)

    # Extracting the phase from the measurement results
    mask            = (1 << n_precision_qubits) - 1
    weight_by_k     = defaultdict(float)
    for sample in result.samples:
        k = sample.index & mask
        weight = getattr(sample, "probability", None)
        if weight is None:
            weight = sample.count
        weight_by_k[k] += weight

    # Picking the k with the largest total weight
    best_k = max(weight_by_k, key=weight_by_k.get)

    # Converting to phase ϕ̂ = k / 2^n
    phase_estimate = best_k / (1 << n_precision_qubits)

    print(f"Estimated phase: {phase_estimate}")
    return phase_estimate

# %%
def eigenstate_1():
    c = QCircuit(1)
    c.add(H(0))
    return c

def unitary_Z():
    c = QCircuit(1)
    c.add(H(0))
    return c

unitary = unitary_Z()
eigenstate = eigenstate_1()

# Expecting 0 or 0.5
phase = extract_phase_from_eigenstate(unitary, eigenstate, n_precision_qubits=3)
# Out:
# Starting Quantum Phase Estimation (QPE) to extract phase from eigenstate.
# Applying controlled unitary operations.
# Applying controlled unitary for precision qubit 2
# Applying controlled unitary 1 times.
# 	1 remaining
# Applying controlled unitary for precision qubit 1
# Applying controlled unitary 2 times.
# 	2 remaining
# 	1 remaining
# Applying controlled unitary for precision qubit 0
# Applying controlled unitary 4 times.
# 	4 remaining
# 	3 remaining
# 	2 remaining
# 	1 remaining
# Controlled unitary operations applied.
# Appending inverse Quantum Fourier Transform (QFT).
# Inverse QFT appended to the circuit.
# Measurement added to precision qubits.
# QCircuit QPE Circuit: Size (Qubits, Cbits) = (4, 3), Nb instructions = 52
#      ┌───┐                                                ░          »
# q_0: ┤ H ├────────────────────────────────────────────────░──────────»
#      ├───┤                                                ░          »
# q_1: ┤ H ├────────────────────────────────────────────────░──────────»
#      ├───┤                                                ░          »
# q_2: ┤ H ├──────────────────────■─────────────────────────░──────────»
#      ├───┤┌───────┐┌─────────┐┌─┴─┐┌────────┐┌──────────┐ ░ ┌───────┐»
# q_3: ┤ H ├┤ Rz(π) ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├┤ Rz(-π/2) ├─░─┤ Rz(π) ├»
#      └───┘└───────┘└─────────┘└───┘└────────┘└──────────┘ ░ └───────┘»
# c: 3/════════════════════════════════════════════════════════════════»
#                                                                      »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_1: ─────────────■──────────────────────────────────────────────■────────────»
# «                  │                                              │            »
# «q_2: ─────────────┼──────────────────────────────────────────────┼────────────»
# «     ┌─────────┐┌─┴─┐┌────────┐┌──────────┐┌───────┐┌─────────┐┌─┴─┐┌────────┐»
# «q_3: ┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├┤ Rz(-π/2) ├┤ Rz(π) ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├»
# «     └─────────┘└───┘└────────┘└──────────┘└───────┘└─────────┘└───┘└────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                  ░                                                         »
# «q_0: ─────────────░───────────────────────■─────────────────────────────────»
# «                  ░                       │                                 »
# «q_1: ─────────────░───────────────────────┼─────────────────────────────────»
# «                  ░                       │                                 »
# «q_2: ─────────────░───────────────────────┼─────────────────────────────────»
# «     ┌──────────┐ ░ ┌───────┐┌─────────┐┌─┴─┐┌────────┐┌──────────┐┌───────┐»
# «q_3: ┤ Rz(-π/2) ├─░─┤ Rz(π) ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├┤ Rz(-π/2) ├┤ Rz(π) ├»
# «     └──────────┘ ░ └───────┘└─────────┘└───┘└────────┘└──────────┘└───────┘»
# «c: 3/═══════════════════════════════════════════════════════════════════════»
# «                                                                            »
# «                                                                              »
# «q_0: ─────────────■──────────────────────────────────────────────■────────────»
# «                  │                                              │            »
# «q_1: ─────────────┼──────────────────────────────────────────────┼────────────»
# «                  │                                              │            »
# «q_2: ─────────────┼──────────────────────────────────────────────┼────────────»
# «     ┌─────────┐┌─┴─┐┌────────┐┌──────────┐┌───────┐┌─────────┐┌─┴─┐┌────────┐»
# «q_3: ┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├┤ Rz(-π/2) ├┤ Rz(π) ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├»
# «     └─────────┘└───┘└────────┘└──────────┘└───────┘└─────────┘└───┘└────────┘»
# «c: 3/═════════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «                                                                 ░         »
# «q_0: ──────────────────────────────────■─────────────────────────░──X──────»
# «                                       │                         ░  │      »
# «q_1: ──────────────────────────────────┼─────────────────────────░──┼──────»
# «                                       │                         ░  │ ┌───┐»
# «q_2: ──────────────────────────────────┼─────────────────────────░──X─┤ H ├»
# «     ┌──────────┐┌───────┐┌─────────┐┌─┴─┐┌────────┐┌──────────┐ ░    └───┘»
# «q_3: ┤ Rz(-π/2) ├┤ Rz(π) ├┤ Rz(π/2) ├┤ X ├┤ Rz(-π) ├┤ Rz(-π/2) ├─░─────────»
# «     └──────────┘└───────┘└─────────┘└───┘└────────┘└──────────┘ ░         »
# «c: 3/══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                        ┌───┐ ░  ░ ┌─┐
# «q_0: ────────────────■─────────■────────┤ H ├─░──░─┤M├──────
# «               ┌───┐ │P(-π/2)  │        └───┘ ░  ░ └╥┘┌─┐
# «q_1: ─■────────┤ H ├─■─────────┼──────────────░──░──╫─┤M├───
# «      │P(-π/2) └───┘           │P(-π/4)       ░  ░  ║ └╥┘┌─┐
# «q_2: ─■────────────────────────■──────────────░──░──╫──╫─┤M├
# «                                              ░  ░  ║  ║ └╥┘
# «q_3: ─────────────────────────────────────────░──░──╫──╫──╫─
# «                                              ░  ░  ║  ║  ║
# «c: 3/═══════════════════════════════════════════════╩══╩══╩═
# «                                                    0  1  2
# Estimated phase: 0.0

# %%
unitary = QCircuit(1)
unitary.add(S(0))
eigenstate = QCircuit(1)
eigenstate.add(X(0))  # |1⟩
n_precision_qubits = 4

# Expecting 0.25
phase = extract_phase_from_eigenstate(unitary, eigenstate, n_precision_qubits)
# Out:
# Starting Quantum Phase Estimation (QPE) to extract phase from eigenstate.
# Applying controlled unitary operations.
# Applying controlled unitary for precision qubit 3
# Applying controlled unitary 1 times.
# 	1 remaining
# Applying controlled unitary for precision qubit 2
# Applying controlled unitary 2 times.
# 	2 remaining
# 	1 remaining
# Applying controlled unitary for precision qubit 1
# Applying controlled unitary 4 times.
# 	4 remaining
# 	3 remaining
# 	2 remaining
# 	1 remaining
# Applying controlled unitary for precision qubit 0
# Applying controlled unitary 8 times.
# 	8 remaining
# 	7 remaining
# 	6 remaining
# 	5 remaining
# 	4 remaining
# 	3 remaining
# 	2 remaining
# 	1 remaining
# Controlled unitary operations applied.
# Appending inverse Quantum Fourier Transform (QFT).
# Inverse QFT appended to the circuit.
# Measurement added to precision qubits.
# QCircuit QPE Circuit: Size (Qubits, Cbits) = (5, 4), Nb instructions = 39
#      ┌───┐          ░                    ░                                     »
# q_0: ┤ H ├──────────░────────────────────░─────────────────────────────────────»
#      ├───┤          ░                    ░                                     »
# q_1: ┤ H ├──────────░────────────────────░──■────────■────────■────────■───────»
#      ├───┤          ░                    ░  │        │        │        │       »
# q_2: ┤ H ├──────────░──■────────■────────░──┼────────┼────────┼────────┼───────»
#      ├───┤          ░  │        │        ░  │        │        │        │       »
# q_3: ┤ H ├─■────────░──┼────────┼────────░──┼────────┼────────┼────────┼───────»
#      ├───┤ │P(π/2)  ░  │P(π/2)  │P(π/2)  ░  │P(π/2)  │P(π/2)  │P(π/2)  │P(π/2) »
# q_4: ┤ X ├─■────────░──■────────■────────░──■────────■────────■────────■───────»
#      └───┘          ░                    ░                                     »
# c: 4/══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «      ░                                                                »
# «q_0: ─░──■────────■────────■────────■────────■────────■────────■───────»
# «      ░  │        │        │        │        │        │        │       »
# «q_1: ─░──┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      ░  │        │        │        │        │        │        │       »
# «q_2: ─░──┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      ░  │        │        │        │        │        │        │       »
# «q_3: ─░──┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      ░  │P(π/2)  │P(π/2)  │P(π/2)  │P(π/2)  │P(π/2)  │P(π/2)  │P(π/2) »
# «q_4: ─░──■────────■────────■────────■────────■────────■────────■───────»
# «      ░                                                                »
# «c: 4/══════════════════════════════════════════════════════════════════»
# «                                                                       »
# «               ░                                                           »
# «q_0: ─■────────░──X───────────────────────────────────────────────■────────»
# «      │        ░  │                                         ┌───┐ │P(-π/2) »
# «q_1: ─┼────────░──┼───X──────────────────■─────────■────────┤ H ├─■────────»
# «      │        ░  │   │            ┌───┐ │P(-π/2)  │        └───┘          »
# «q_2: ─┼────────░──┼───X───■────────┤ H ├─■─────────┼───────────────────────»
# «      │        ░  │ ┌───┐ │P(-π/2) └───┘           │P(-π/4)                »
# «q_3: ─┼────────░──X─┤ H ├─■────────────────────────■───────────────────────»
# «      │P(π/2)  ░    └───┘                                                  »
# «q_4: ─■────────░───────────────────────────────────────────────────────────»
# «               ░                                                           »
# «c: 4/══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                         ┌───┐ ░  ░ ┌─┐
# «q_0: ─■─────────■────────┤ H ├─░──░─┤M├─────────
# «      │         │        └───┘ ░  ░ └╥┘┌─┐
# «q_1: ─┼─────────┼──────────────░──░──╫─┤M├──────
# «      │P(-π/4)  │              ░  ░  ║ └╥┘┌─┐
# «q_2: ─■─────────┼──────────────░──░──╫──╫─┤M├───
# «                │P(-π/8)       ░  ░  ║  ║ └╥┘┌─┐
# «q_3: ───────────■──────────────░──░──╫──╫──╫─┤M├
# «                               ░  ░  ║  ║  ║ └╥┘
# «q_4: ──────────────────────────░──░──╫──╫──╫──╫─
# «                               ░  ░  ║  ║  ║  ║
# «c: 4/════════════════════════════════╩══╩══╩══╩═
# «                                     0  1  2  3
# Estimated phase: 0.25

# %%
unitary = QCircuit(1); unitary.add(T(0))
eigenstate = QCircuit(1); eigenstate.add(X(0))  # |1⟩
n_precision_qubits = 5

# Expecting 0.125
phase = extract_phase_from_eigenstate(unitary, eigenstate, n_precision_qubits)
# Out:
# Starting Quantum Phase Estimation (QPE) to extract phase from eigenstate.
# Applying controlled unitary operations.
# Applying controlled unitary for precision qubit 4
# Applying controlled unitary 1 times.
# 	1 remaining
# Applying controlled unitary for precision qubit 3
# Applying controlled unitary 2 times.
# 	2 remaining
# 	1 remaining
# Applying controlled unitary for precision qubit 2
# Applying controlled unitary 4 times.
# 	4 remaining
# 	3 remaining
# 	2 remaining
# 	1 remaining
# Applying controlled unitary for precision qubit 1
# Applying controlled unitary 8 times.
# 	8 remaining
# 	7 remaining
# 	6 remaining
# 	5 remaining
# 	4 remaining
# 	3 remaining
# 	2 remaining
# 	1 remaining
# Applying controlled unitary for precision qubit 0
# Applying controlled unitary 16 times.
# 	16 remaining
# 	15 remaining
# 	14 remaining
# 	13 remaining
# 	12 remaining
# 	11 remaining
# 	10 remaining
# 	9 remaining
# 	8 remaining
# 	7 remaining
# 	6 remaining
# 	5 remaining
# 	4 remaining
# 	3 remaining
# 	2 remaining
# 	1 remaining
# Controlled unitary operations applied.
# Appending inverse Quantum Fourier Transform (QFT).
# Inverse QFT appended to the circuit.
# Measurement added to precision qubits.
# QCircuit QPE Circuit: Size (Qubits, Cbits) = (6, 5), Nb instructions = 62
#      ┌───┐          ░                    ░                                     »
# q_0: ┤ H ├──────────░────────────────────░─────────────────────────────────────»
#      ├───┤          ░                    ░                                     »
# q_1: ┤ H ├──────────░────────────────────░─────────────────────────────────────»
#      ├───┤          ░                    ░                                     »
# q_2: ┤ H ├──────────░────────────────────░──■────────■────────■────────■───────»
#      ├───┤          ░                    ░  │        │        │        │       »
# q_3: ┤ H ├──────────░──■────────■────────░──┼────────┼────────┼────────┼───────»
#      ├───┤          ░  │        │        ░  │        │        │        │       »
# q_4: ┤ H ├─■────────░──┼────────┼────────░──┼────────┼────────┼────────┼───────»
#      ├───┤ │P(π/4)  ░  │P(π/4)  │P(π/4)  ░  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4) »
# q_5: ┤ X ├─■────────░──■────────■────────░──■────────■────────■────────■───────»
#      └───┘          ░                    ░                                     »
# c: 5/══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «      ░                                                                »
# «q_0: ─░────────────────────────────────────────────────────────────────»
# «      ░                                                                »
# «q_1: ─░──■────────■────────■────────■────────■────────■────────■───────»
# «      ░  │        │        │        │        │        │        │       »
# «q_2: ─░──┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      ░  │        │        │        │        │        │        │       »
# «q_3: ─░──┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      ░  │        │        │        │        │        │        │       »
# «q_4: ─░──┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      ░  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4) »
# «q_5: ─░──■────────■────────■────────■────────■────────■────────■───────»
# «      ░                                                                »
# «c: 5/══════════════════════════════════════════════════════════════════»
# «                                                                       »
# «               ░                                                       »
# «q_0: ──────────░──■────────■────────■────────■────────■────────■───────»
# «               ░  │        │        │        │        │        │       »
# «q_1: ─■────────░──┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │        ░  │        │        │        │        │        │       »
# «q_2: ─┼────────░──┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │        ░  │        │        │        │        │        │       »
# «q_3: ─┼────────░──┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │        ░  │        │        │        │        │        │       »
# «q_4: ─┼────────░──┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │P(π/4)  ░  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4) »
# «q_5: ─■────────░──■────────■────────■────────■────────■────────■───────»
# «               ░                                                       »
# «c: 5/══════════════════════════════════════════════════════════════════»
# «                                                                       »
# «                                                                             »
# «q_0: ─■────────■────────■────────■────────■────────■────────■────────■───────»
# «      │        │        │        │        │        │        │        │       »
# «q_1: ─┼────────┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │        │        │        │        │        │        │        │       »
# «q_2: ─┼────────┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │        │        │        │        │        │        │        │       »
# «q_3: ─┼────────┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │        │        │        │        │        │        │        │       »
# «q_4: ─┼────────┼────────┼────────┼────────┼────────┼────────┼────────┼───────»
# «      │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4)  │P(π/4) »
# «q_5: ─■────────■────────■────────■────────■────────■────────■────────■───────»
# «                                                                             »
# «c: 5/════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                        ░                                                 »
# «q_0: ─■────────■────────░──X──────────────────────────────────────────────»
# «      │        │        ░  │                                              »
# «q_1: ─┼────────┼────────░──┼───X──────────────────────────────────────────»
# «      │        │        ░  │   │                                     ┌───┐»
# «q_2: ─┼────────┼────────░──┼───┼──────────────────■─────────■────────┤ H ├»
# «      │        │        ░  │   │            ┌───┐ │P(-π/2)  │        └───┘»
# «q_3: ─┼────────┼────────░──┼───X───■────────┤ H ├─■─────────┼─────────────»
# «      │        │        ░  │ ┌───┐ │P(-π/2) └───┘           │P(-π/4)      »
# «q_4: ─┼────────┼────────░──X─┤ H ├─■────────────────────────■─────────────»
# «      │P(π/4)  │P(π/4)  ░    └───┘                                        »
# «q_5: ─■────────■────────░─────────────────────────────────────────────────»
# «                        ░                                                 »
# «c: 5/═════════════════════════════════════════════════════════════════════»
# «                                                                          »
# «                                                                      »
# «q_0: ────────────────────────────────────■─────────■─────────■────────»
# «                                   ┌───┐ │P(-π/2)  │         │        »
# «q_1: ─■─────────■─────────■────────┤ H ├─■─────────┼─────────┼────────»
# «      │P(-π/2)  │         │        └───┘           │P(-π/4)  │        »
# «q_2: ─■─────────┼─────────┼────────────────────────■─────────┼────────»
# «                │P(-π/4)  │                                  │P(-π/8) »
# «q_3: ───────────■─────────┼──────────────────────────────────■────────»
# «                          │P(-π/8)                                    »
# «q_4: ─────────────────────■───────────────────────────────────────────»
# «                                                                      »
# «q_5: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «c: 5/═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «                ┌───┐ ░  ░ ┌─┐
# «q_0: ─■─────────┤ H ├─░──░─┤M├────────────
# «      │         └───┘ ░  ░ └╥┘┌─┐
# «q_1: ─┼───────────────░──░──╫─┤M├─────────
# «      │               ░  ░  ║ └╥┘┌─┐
# «q_2: ─┼───────────────░──░──╫──╫─┤M├──────
# «      │               ░  ░  ║  ║ └╥┘┌─┐
# «q_3: ─┼───────────────░──░──╫──╫──╫─┤M├───
# «      │P(-π/16)       ░  ░  ║  ║  ║ └╥┘┌─┐
# «q_4: ─■───────────────░──░──╫──╫──╫──╫─┤M├
# «                      ░  ░  ║  ║  ║  ║ └╥┘
# «q_5: ─────────────────░──░──╫──╫──╫──╫──╫─
# «                      ░  ░  ║  ║  ║  ║  ║
# «c: 5/═══════════════════════╩══╩══╩══╩══╩═
# «                            0  1  2  3  4
# Estimated phase: 0.125
